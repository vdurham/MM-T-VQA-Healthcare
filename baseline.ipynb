# %%
# only one run per machine
# !git clone https://github.com/vdurham/MM-T-VQA-Healthcare.git
# %cd IDLProject
# !git pull origin main
# !pip install transformers
# !pip install datasets

# %%
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

url = "microsoft/BiomedVLP-BioViL-T"
model = AutoModelForSequenceClassification.from_pretrained(model_name, cache_dir='./model')
tokenizer = AutoTokenizer.from_pretrained(model_name, cache_dir='./model')
